# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Top5000.csv')

# %%
df.columns
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['ars_name', 'rel_date', 'gens', 'descs', 'avg_rat', 'num_rat',
#        'num_revs', 'album', 'acousticness', 'danceability', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
"""'ars_name', 'rel_date', 'gens', 'descs', 'avg_rat', 'num_rat',
       'num_revs', 'album', 'acousticness', 'danceability', 'energy',
       'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
       'valence', 'duration_ms', 'time_signature'"""

df.head()
# Out:
#          ars_name           rel_date  \
# 0       Radiohead       16 June 1997
# 1      Pink Floyd  12 September 1975
# 2    King Crimson    10 October 1969
# 3       Radiohead     3 October 2000
# 4  Kendrick Lamar      15 March 2015
#
#                                               gens  \
# 0                       Alternative Rock, Art Rock
# 1                       Progressive Rock, Art Rock
# 2                       Progressive Rock, Art Rock
# 3          Art Rock, Experimental Rock, Electronic
# 4  Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
#
#                                                descs  avg_rat num_rat  \
# 0  melancholic, anxious, futuristic, alienation, ...     4.23  70,382
# 1  melancholic, atmospheric, progressive, male vo...     4.29  48,662
# 2  fantasy, epic, progressive, philosophical, com...     4.30  44,943
# 3  cold, melancholic, futuristic, atmospheric, an...     4.21  58,590
# 4  political, conscious, poetic, protest, concept...     4.27  44,206
#
# ...

# %%
df.describe()
df.info()
df.isnull().sum()
df.isnull().sum()/len(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4402 entries, 0 to 4401
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ars_name          4402 non-null   object
#  1   rel_date          4402 non-null   object
#  2   gens              4402 non-null   object
#  3   descs             4304 non-null   object
#  4   avg_rat           4402 non-null   float64
#  5   num_rat           4402 non-null   object
#  6   num_revs          4402 non-null   int64
#  7   album             4402 non-null   object
#  8   acousticness      4402 non-null   float64
#  9   danceability      4402 non-null   float64
#  10  energy            4402 non-null   float64
#  11  instrumentalness  4402 non-null   float64
#  12  liveness          4402 non-null   float64
#  13  loudness          4402 non-null   float64
#  14  speechiness       4402 non-null   float64
#  15  tempo             4402 non-null   float64
# ...

# %%
top_10 = df.sort_values(by='avg_rat', ascending=False).head(10)
top_10.head()
# Out:
#           ars_name           rel_date  \
# 13          Mingus          July 1963
# 2     King Crimson    10 October 1969
# 15   John Coltrane      February 1965
# 1       Pink Floyd  12 September 1975
# 4   Kendrick Lamar      15 March 2015
#
#                                                gens  \
# 13                   Avant-Garde Jazz, Third Stream
# 2                        Progressive Rock, Art Rock
# 15                                   Spiritual Jazz
# 1                        Progressive Rock, Art Rock
# 4   Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
#
#                                                 descs  avg_rat num_rat  \
# 13  instrumental, complex, passionate, suite, dens...     4.34  20,251
# 2   fantasy, epic, progressive, philosophical, com...     4.30  44,943
# 15  passionate, spiritual, instrumental, improvisa...     4.30  25,040
# 1   melancholic, atmospheric, progressive, male vo...     4.29  48,662
# ...

# %%
top_10_year = df.groupby('rel_date').head(10)
top_10_year.head()
# Out:
#          ars_name           rel_date  \
# 0       Radiohead       16 June 1997
# 1      Pink Floyd  12 September 1975
# 2    King Crimson    10 October 1969
# 3       Radiohead     3 October 2000
# 4  Kendrick Lamar      15 March 2015
#
#                                               gens  \
# 0                       Alternative Rock, Art Rock
# 1                       Progressive Rock, Art Rock
# 2                       Progressive Rock, Art Rock
# 3          Art Rock, Experimental Rock, Electronic
# 4  Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
#
#                                                descs  avg_rat num_rat  \
# 0  melancholic, anxious, futuristic, alienation, ...     4.23  70,382
# 1  melancholic, atmospheric, progressive, male vo...     4.29  48,662
# 2  fantasy, epic, progressive, philosophical, com...     4.30  44,943
# 3  cold, melancholic, futuristic, atmospheric, an...     4.21  58,590
# 4  political, conscious, poetic, protest, concept...     4.27  44,206
#
# ...

# %%
top_10.plot(kind='bar', x='ars_name', y='avg_rat')
plt.show()

# %%
top_10_year.plot(kind='bar', x='rel_date', y='avg_rat')
plt.show()
